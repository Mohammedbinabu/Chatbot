# %% [markdown]
# **Text Splitting technique (Recursive Character Text-Splitter**)

# %%
from langchain_community.document_loaders import PyPDFLoader
# %pip install pypdf
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pdf_loader = PyPDFLoader('Purchase Order 5500015337 _ SLI.PDF')
pdf = pdf_loader.load()

# %%
pdf
# Out:
# [Document(metadata={'producer': 'SAP NetWeaver 750', 'creator': 'Form ZMM_MEDRUCK_FAB EN', 'creationdate': 'D:20240311000006', 'author': 'BC-BATCH', 'source': 'Purchase Order 5500015337 _ SLI.PDF', 'total_pages': 4, 'page': 0, 'page_label': '1'}, page_content='PURCHASE ORDER\nSilicon Laboratories Intl Pte Ltd\n18 Tai Seng Street #05-01\n18 Tai Seng\nSINGAPORE 539775\nSINGAPORE\nPh: 6511 7777\nFax: 6511 7702\nOrder Contact : Purchasing Dept.\nRelease PO Number / Version / Date\n5500015337 / 00 / 03/10/2024\nSilicon Labs Contact/Telephone/E-mail\nYANXIAN HEW\nYanXian.Hew@silabs.com\nYour Vendor Number with us is:\n107643\nEmbedded IT Solutions (I)\nPvt. Ltd.\nParvatheesam\nP.No.5, Fabcity SEZ, Sreenagar(V)\nMaheswaram (MD)\nRangareddy (DT)\n501359 Hyderabad\nPhone:70322666101\nFax:\nValue Contract Number Related to this order\n4600004657\nShip To Attn: As per shipment instructions\nZ001\nSLI VIRTUAL PLANT\nBill To Attn: Silicon Laboratories Intl Pte Ltd\nAccounts Payable Dept\n18 Tai S
# ...

# %% [markdown]
# **Text-Splitting**

# %%
# %pip install langchain_text_splitters
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
type(pdf)
# Out:
# list

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=50)
chunks = splitter.split_documents(pdf)

# %%
chunks[0]
chunks[1]
# Out:
# Document(metadata={'producer': 'SAP NetWeaver 750', 'creator': 'Form ZMM_MEDRUCK_FAB EN', 'creationdate': 'D:20240311000006', 'author': 'BC-BATCH', 'source': 'Purchase Order 5500015337 _ SLI.PDF', 'total_pages': 4, 'page': 0, 'page_label': '1'}, page_content='18 Tai Seng Street #05-01\n18 Tai Seng\nSINGAPORE 539775\nSINGAPORE\nPh: 6511 7777\nFax: 6511 7702')

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader('TEXT_FILE.txt')
text = loader.load()

# %%
text
# Out:
# [Document(metadata={'source': 'TEXT_FILE.txt'}, page_content='William Shakespeare[a] (c. 23[b] April 1564 – 23 April 1616)[c] was an English playwright, poet and actor. He is widely regarded as the greatest writer in the English language and the world\'s pre-eminent dramatist. He is often called England\'s national poet and the "Bard of Avon" (or simply "the Bard"). His extant works, including collaborations, consist of some 39 plays, 154 sonnets, three long narrative poems and a few other verses, some of uncertain authorship. His plays have been translated into every major living language and are performed more often than those of any other playwright. Shakespeare remains arguably the most influential writer in the English language, and his works continue to be studied and reinterpreted.\n\nShakespeare was born and raised in Stratford-upon-Avon, Warwickshire. At the age of 18, he married Anne Hathaway, with whom he had three children: Susanna, and twins Hamnet and Judith. Sometime b
# ...

# %%
speech = ""
with open("TEXT_FILE.txt", "w") as f:
    speech = f.read()

speech
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[41], line 3
#       1 speech = ""
#       2 with open("TEXT_FILE.txt", "w") as f:
# ----> 3     speech = f.read()
#       5 speech
#
# UnsupportedOperation: not readable

# %%
text_split = RecursiveCharacterTextSplitter(chunk_size=100,chunk_overlap=20)
split_text = text_split.split_documents(speech)
